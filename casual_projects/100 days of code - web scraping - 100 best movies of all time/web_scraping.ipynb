# %%
import requests
from bs4 import BeautifulSoup

URL = "https://app.adroll.com/backstage/celerytasks/hud"

# %%
responsne = requests.get(URL)
string = responsne.text
print(string)
# Out:
# <!doctype html>
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!-- Consider adding a manifest.appcache: h5bp.com/d/Offline -->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
#   <!-- META INFO -->
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="google-site-verification" content="E-oZsvbsAoStuZuRfIjBe0r1CRp1mia5VnNBfD-RHwM" />
#     <meta name="description" content="AdRoll is a simple and effective platform for advertising online and retargeting previous website visitors to bring them back to your site.'">
# ...
