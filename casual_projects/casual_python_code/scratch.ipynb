# %%
from linked_list import Node, LinkedList
import random

def random_data_generator():
    name = ['Jagan', 'Preethi', 'jayashree', 'mohan', 'srimadhi', 'shivanya', 'annapoorani', 'babu']
    return {'name' : random.choice(name),
            'score': random.randint(50, 100)}

ll = LinkedList()
for i in range(1, 101):
    ll.append(Node(random_data_generator()))

# %%
ll.print()
# Out:
# {'name': 'mohan', 'score': 96}
# {'name': 'shivanya', 'score': 67}
# {'name': 'jayashree', 'score': 63}
# {'name': 'babu', 'score': 70}
# {'name': 'Jagan', 'score': 63}
# {'name': 'jayashree', 'score': 88}
# {'name': 'shivanya', 'score': 73}
# {'name': 'babu', 'score': 54}
# {'name': 'babu', 'score': 100}
# {'name': 'mohan', 'score': 77}
# {'name': 'srimadhi', 'score': 56}
# {'name': 'Jagan', 'score': 87}
# {'name': 'babu', 'score': 58}
# {'name': 'Jagan', 'score': 100}
# {'name': 'mohan', 'score': 95}
# {'name': 'mohan', 'score': 98}
# {'name': 'Jagan', 'score': 97}
# {'name': 'Preethi', 'score': 51}
# {'name': 'babu', 'score': 70}
# {'name': 'annapoorani', 'score': 81}
# {'name': 'Preethi', 'score': 60}
# {'name': 'Preethi', 'score': 60}
# {'name': 'babu', 'score': 91}
# {'name': 'babu', 'score': 77}
# {'name': 'jayashree', 'score': 53}
# {'name': 'srimadhi', 'score': 59}
# {'name': 'babu', 'score': 78}
# {'name': 'shivanya', 'score': 97}
# {'name': 'jayashree', 'score': 50}
# {'name': 'shivanya', 'score': 89}
# {'name': 'Jagan', 'score': 62}
# {'name': 'mohan', 'score': 72}
# {'name': 'Preethi', 'score': 56}
# {'name': 'mohan', 'score': 82}
# {'name': 'Preethi', 'score': 64}
# {'name': 'shivanya', 'score': 80}
# {'name': 'babu', 'score': 51}
# {'name': 'Preethi', 'score': 65}
# {'name': 'babu', 'score': 83}
# {'name': 'srimadhi', 'score': 53}
# {'name': 'annapoorani', 'score': 90}
# {'name': 'srimadhi', 'score': 65}
# {'name': 'shivanya', 'score': 78}
# {'name': 'babu', 'score': 99}
# {'name': 'Jagan', 'score': 53}
# {'name': 'shivanya', 'score': 91}
# {'name': 'annapoorani', 'score': 57}
# {'name': 'mohan', 'score': 88}
# {'name': 'mohan', 'score': 81}
# {'name': 'Jagan', 'score': 66}
# {'name': 'annapoorani', 'score': 76}
# {'name': 'Jagan', 'score': 89}
# {'name': 'Preethi', 'score': 73}
# {'name': 'srimadhi', 'score': 76}
# {'name': 'Preethi', 'score': 58}
# {'name': 'jayashree', 'score': 83}
# {'name': 'srimadhi', 'score': 76}
# {'name': 'Preethi', 'score': 57}
# {'name': 'Preethi', 'score': 61}
# {'name': 'shivanya', 'score': 74}
# {'name': 'jayashree', 'score': 58}
# {'name': 'babu', 'score': 70}
# {'name': 'mohan', 'score': 85}
# {'name': 'babu', 'score': 98}
# {'name': 'annapoorani', 'score': 67}
# {'name': 'jayashree', 'score': 67}
# {'name': 'babu', 'score': 72}
# {'name': 'babu', 'score': 69}
# {'name': 'annapoorani', 'score': 90}
# {'name': 'jayashree', 'score': 53}
# {'name': 'shivanya', 'score': 95}
# {'name': 'jayashree', 'score': 61}
# {'name': 'Preethi', 'score': 74}
# {'name': 'jayashree', 'score': 76}
# {'name': 'shivanya', 'score': 92}
# {'name': 'shivanya', 'score': 62}
# {'name': 'mohan', 'score': 77}
# {'name': 'shivanya', 'score': 99}
# {'name': 'srimadhi', 'score': 72}
# {'name': 'annapoorani', 'score': 89}
# {'name': 'jayashree', 'score': 79}
# {'name': 'annapoorani', 'score': 71}
# {'name': 'babu', 'score': 100}
# {'name': 'annapoorani', 'score': 67}
# {'name': 'Jagan', 'score': 60}
# {'name': 'shivanya', 'score': 85}
# {'name': 'srimadhi', 'score': 84}
# {'name': 'annapoorani', 'score': 98}
# {'name': 'mohan', 'score': 58}
# {'name': 'Preethi', 'score': 87}
# {'name': 'srimadhi', 'score': 82}
# {'name': 'srimadhi', 'score': 87}
# {'name': 'annapoorani', 'score': 58}
# {'name': 'jayashree', 'score': 74}
# {'name': 'Preethi', 'score': 68}
# {'name': 'shivanya', 'score': 56}
# {'name': 'srimadhi', 'score': 61}
# {'name': 'mohan', 'score': 97}
# {'name': 'Jagan', 'score': 85}
# {'name': 'jayashree', 'score': 64}
